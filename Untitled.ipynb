# %%
import ipywidgets as widgets
from ipywidgets import HBox, VBox, Layout, Box, ButtonStyle
import matplotlib.pyplot as plt
import numpy as np
import plotly.express as px
import plotly.graph_objects as go
from plotly.subplots import make_subplots
# %matplotlib inline


conv_plt = widgets.Output()
tit = widgets.HTML(value="<h4>TEST</h4>")
f = go.FigureWidget()

plots = VBox(children=[f])
app = Box(children=[tit, plots])
app
# Out:
# Box(children=(HTML(value='<h4>TEST</h4>'), VBox(children=(FigureWidget({
#     'data': [], 'layout': {'template'…

# %%
x=np.linspace(0,1,100)
f.add_scatter(fill="tozeroy")
# f.d
# rgb(215, 95, 83)
f.layout.template = 'plotly_white'
for i in range(15):
    opthist = {}
    opthist["iterations"] = np.array(range(i))
    opthist["objective"] = np.array(range(i))**2
    scatter = f.data[0]
    scatter.y = x**i

# %%
f.layout.xaxis.title="swsp"

# %%
f.data
# Out:
# (Scatter({
#      'fill': 'tozeroy',
#      'uid': 'e5e9808b-c174-4540-aca4-42b4fdb1d3e8',
#      'y': array([0.00000000e+00, 1.15108468e-28, 1.88593715e-24, 5.50560236e-22,
#                  3.08991942e-20, 7.02566336e-19, 9.02037891e-18, 7.80692192e-17,
#                  5.06252398e-16, 2.63331254e-15, 1.15108468e-14, 4.37124217e-14,
#                  1.47789888e-13, 4.53225366e-13, 1.27908609e-12, 3.36035301e-12,
#                  8.29443929e-12, 1.93817137e-11, 4.31441927e-11, 9.19724359e-11,
#                  1.88593715e-10, 3.73402655e-10, 7.16184318e-10, 1.33443363e-09,
#                  2.42138953e-09, 4.28812461e-09, 7.42564439e-09, 1.25950523e-08,
#                  2.09565465e-08, 3.42514724e-08, 5.50560236e-08, 8.71306571e-08,
#                  1.35896093e-07, 2.09075158e-07, 3.17549998e-07, 4.76496699e-07,
#                  7.06874453e-07, 1.03736457e-06, 1.50687639e-06, 2.16776287e-06,
# ...

# %%
f = go.FigureWidget()
f.add_contour()
cont =  f.data[0]
z=[[10, 10.625, 12.5, 15.625, 20],
           [5.625, 6.25, 8.125, 11.25, 15.625],
           [2.5, 3.125, 5., 8.125, 12.5],
           [0.625, 1.25, 3.125, 6.25, 10.625],
           [0, 0.625, 2.5, 5.625, 10]]
cont.z = z
f
# Out:
# FigureWidget({
#     'data': [{'type': 'contour',
#               'uid': '91cdcfae-23eb-4840-8572-3eb59135f28c',
#  …
